# %% [markdown]
# # cardio good fitness case study - descriptive statistics

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("/home/bot/Desktop/interships/yhills/datasets/CardioGoodFitness-1 (1).csv")

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.shape
# Out:
# (180, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
#mean==median then it is normally distributes

# %%
df.describe(include='all').T
# Out:
#                count unique        top freq          mean           std  \
# Product          180      3      TM195   80           NaN           NaN
# Age            180.0    NaN        NaN  NaN     28.788889      6.943498
# Gender           180      2       Male  104           NaN           NaN
# Education      180.0    NaN        NaN  NaN     15.572222      1.617055
# MaritalStatus    180      2  Partnered  107           NaN           NaN
# Usage          180.0    NaN        NaN  NaN      3.455556      1.084797
# Fitness        180.0    NaN        NaN  NaN      3.311111      0.958869
# Income         180.0    NaN        NaN  NaN  53719.577778  16506.684226
# Miles          180.0    NaN        NaN  NaN    103.194444     51.863605
#
#                    min       25%      50%      75%       max
# Product            NaN       NaN      NaN      NaN       NaN
# Age               18.0      24.0     26.0     33.0      50.0
# Gender             NaN       NaN      NaN      NaN       NaN
# ...

# %% [markdown]
# #missing value
# categorical dataa->mode
# numerical data(no outliers)->mean/median
#
#
# numerical daata(with outilesr)-median

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(df['Income'])
# Out:
# <Axes: xlabel='Income', ylabel='Density'>

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
# # # #descriptive and inferential statistics

# # # statistics-science of collecting,organizing,analyzing data
# # # data-facets or piece of info
# # # data may be qualitative and quatitative
# # pupulation and sameple you know


# diff between dis and ifrential statisstics


# *describe characterstics of data     * making predictins using data.
# *used charts and graphs              * draws conclusng making comparisions and relationships and hypothesis
# *smalll dataset                      * large dataset(result in the form of probability)


#missing values in categorical data-> replace mode
#missig values in numerical with no outliers ->median
#i
#in any problem should have  1 dependent and n independent variable
#formula for variance of popula tion /n  sample /n-1

# %%
df.hist(figsize=[10,20])
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Education'}>],
#        [<Axes: title={'center': 'Usage'}>,
#         <Axes: title={'center': 'Fitness'}>],
#        [<Axes: title={'center': 'Income'}>,
#         <Axes: title={'center': 'Miles'}>]], dtype=object)

# %%
#outlier is a data point which is different/distanct from all other data points.
#outlier occurs due to variability of data and errors.
#outliers impact inferece of.

#mean is accurate measure to describe data if no outliers are present.
#median if there is outlier is present
#mode if there is outlier and freq of one of the value is high

#we can find outlier using scatterplot,boxplot,z score,iqr -interquantile range.

# %%
#box plot - 5 number summary
#beyong minimum and max are outliers

# %%
iqr=33-24
iqr
# Out:
# 9

# %%
24-1.5*iqr #below 10.5 is outlier
# Out:
# 10.5

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
corr=df.corr()

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
def remove_outlier(col):
    sorted(col)
    q1=col.quantile(0.25)
    q3=col.quantile(0.75)
    iqr=q3-q1
    lowerRange=q1-(1.5*iqr)
    higherRange=q3+(1.5*iqr)
    return lowerRange,higherRange
lowincome,upincome=remove_outlier(df1['mpg'])
df1['mpg']=np.where(df1['mpg']>upincome,upincome,df1['mpg'])
df1['mpg']=np.where(df1['mpg']<lowincome,lowincome,df1['mpg'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 9
#       7     higherRange=q3+(1.5*iqr)
#       8     return lowerRange,higherRange
# ----> 9 lowincome,upincome=remove_outlier(df1['mpg'])
#      10 df1['mpg']=np.where(df1['mpg']>upincome,upincome,df1['mpg'])
#      11 df1['mpg']=np.where(df1['mpg']<lowincome,lowincome,df1['mpg'])
#
# NameError: name 'df1' is not defined
